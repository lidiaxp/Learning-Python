# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
import numpy as np
import random

# %%
# Produto escalar de duas listas numéricas
dotp = lambda v1, v2: sum([x*y for x,y in zip(v1, v2)])

# %%
# Iniciar população aleatóriamente
def startPop(size):
    pop = []
    for i in range(size):
        # Nosso alfabeto será inteiros entre 4 e 188
        pop.append(list(np.random.random_integers(4,177,5)))

    # Adicionar coluna de fitness
    for i in pop:
        i.append(fitness(i))

    # Ordenar por fitness
    pop.sort(key=lambda x: x[5], reverse=True)
    return pop

# %%
# Cálculo dafitness dado um indivíduo
def fitness(vec):
    pesos = [2, 4, 5, 8, 12] #pesos de cada tipo
    valores = [3, 6, 10, 18, 25] #valor de cada tipo
    pesoMax = 500

    # O peso e o valor de cada indivíduo
    # será o produto escalar entre o
    # vetor de pesos e valores e a quantidade 
    # de cada tipo no indivíduo
    pesoInd = dotp(vec, pesos)
    valorInd = dotp(vec, valores)

    if (pesoInd <= pesoMax):
        return valorInd
    # Punição para o caso de o peso exceder o max
    else:
        return valorInd - 24 * (pesoInd - pesoMax)

# %%
# Seleção de pais por torneio
def torneio(pop, tx, nCandidatos):
    popPais = []
    # Sempre seleciona um n par de pais
    nFilhos = 2 * int(len(pop) * tx / 2)

    for i in range(nFilhos):
        # Amostrar candidatos aleatóriamente
        candidatos = random.sample(pop, nCandidatos)
        #print(pop)
        popPais.append(candidatos[0])
        bestFitness = candidatos[0][5]
        #selecionar apenas o de maior fitness
        for j in candidatos:
            if(j[5] > bestFitness):
                popPais = popPais[:-1]
                popPais.append(j)
                bestFitness = j[5]
                
    return popPais

# %%
# Cruzamento por máscara binária dada a população de pais
def cruzamento(popPais):
    popFilhos = []
    # Cruzar população de pais dois a dois
    for i,k in zip(popPais[0::2], popPais[1::2]):
        filho1 = []
        filho2 = []
        # Máscara binária aleatória
        mask = np.random.randint(2, size=5)
        # Cruzamento de acordo com a máscara
        for j in range(len(mask)):
            if(mask[j]):
                filho1.append(i[j])
                filho2.append(k[j])
            else:
                filho1.append(k[j])
                filho2.append(i[j])
        # Cálcular a fitness dos filhos
        filho1.append(fitness(filho1))
        filho2.append(fitness(filho2))
        popFilhos.append(filho1)
        popFilhos.append(filho2)
    return popFilhos

# %%
#Adicionar filhos na população
def inserirFilhos(pop, popFilhos):
    # Eliminar piores indivíduos da população
    pop = pop[:-len(popFilhos)]
    #inserir indivíduos filhos
    for i in popFilhos:
        pop.append(i)
    #organizar a população por fitness
    pop.sort(key=lambda x: x[5], reverse=True)
    return pop

# %%
# Mutar n indivíduos aleatóriamente
def mutacao(pop, tx):
    nMutados = int(len(pop) * tx)
    elitismo = True

    for i in range(nMutados):
        # Se houver elitismo, nunca se muta o melhor indivíduo
        #index do indivíduo a ser mutado
        if (elitismo):
            index1 = np.random.random_integers(1, len(pop) - 1, 1)[0]
        else:
            index1 = np.random.random_integers(0, len(pop) - 1, 1)[0]
        #index do gene a ser mutado
        index2 = np.random.random_integers(0, 4, 1)[0]
        pop[index1][index2] = np.random.random_integers(4,188,1)[0]
        # Recálculo da fitness
        pop[index1][5] = fitness(pop[index1])
    # Reornganização da população
    pop.sort(key=lambda x: x[5], reverse=True)
    return pop

# %%
def Roleta(pop, tx, nt):
    popPais = []
    
    n = 2 * (len(pop) * tx / 2)
    
    for i in range(int(n)):
        rol = 0
        better = [] # guarda o fitness
        miniPop = [] # guarda a populacao selecionada
        val = [] # guarda as porcentagens
        for j in range(int(nt)):
            miniPop.append(pop[random.randint(0, len(pop) - 1)])
            
        for j in miniPop:
            better.append(j[0])
            
        for j in range(int(nt)):
            percent = (sum(better)/better[j]) * 100
            val.append(percent)
            
        roleta = random.randint(0,99)
        
        for j in range(int(nt)):
            rol += val[j]
            
            if roleta <= rol:
                popPais.append(miniPop[j])

    return popPais

# %%
# Listas que serão plotadas
bestIndFit = []
mediumFit = []

pop = startPop(100)

nGerações = 100
taxaDeCruzamento = 0.5
taxaDeMutacao = 0.2

for i in range(nGerações):
    popPais = torneio(pop, taxaDeCruzamento, 3)
    popFilhos = cruzamento(popPais)
    pop = inserirFilhos(pop, popFilhos)
    pop = mutacao(pop, taxaDeMutacao)
    print(f'Geração {i} -- Melhor Indivíduo: {pop[0]} -- Peso: {dotp([2, 4, 5 , 8, 12], pop[0])}\n')
    bestIndFit.append(pop[0][5])
    mediumFit.append(np.mean(pop, axis=0)[5])

# Plot da fitness
fig = Figure()
FigureCanvas(fig)
ax = fig.add_subplot(111)
ax.plot(bestIndFit, label='Fitness do Melhor Indivíduo')
ax.plot(mediumFit, '-.', label='Fitness Média da População')
#ax.set_title('Fitness ao Longo das Gerações')
ax.set_xlabel('Geração')
ax.set_ylabel('Fitness')
ax.set_yscale('symlog')
ax.set_xlim(0,99)
ax.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='center',
       ncol=2, borderaxespad=0)
#fig.savefig('fit_Roleta_mascara.png')
# Out:
# C:\Users\lidiaxp\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: This function is deprecated. Please call randint(4, 177 + 1) instead
#
# C:\Users\lidiaxp\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: This function is deprecated. Please call randint(1, 99 + 1) instead
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\lidiaxp\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: This function is deprecated. Please call randint(0, 4 + 1) instead
#
# C:\Users\lidiaxp\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(4, 188 + 1) instead
#   from ipykernel import kernelapp as app
# Geração 0 -- Melhor Indivíduo: [5, 13, 51, 48, 30, -11247] -- Peso: 1061
#
# Geração 1 -- Melhor Indivíduo: [19, 49, 34, 36, 16, -7477] -- Peso: 884
#
# Geração 2 -- Melhor Indivíduo: [126, 18, 40, 17, 14, -6330] -- Peso: 828
#
# Geração 3 -- Melhor Indivíduo: [66, 6, 38, 32, 5, -2573] -- Peso: 662
#
# Geração 4 -- Melhor Indivíduo: [19, 6, 38, 32, 5, -458] -- Peso: 568
#
# Geração 5 -- Melhor Indivíduo: [19, 6, 38, 32, 5, -458] -- Peso: 568
#
# Geração 6 -- Melhor Indivíduo: [19, 16, 40, 17, 5, 984] -- Peso: 498
#
# Geração 7 -- Melhor Indivíduo: [5, 13, 7, 36, 7, 986] -- Peso: 469
#
# Geração 8 -- Melhor Indivíduo: [5, 13, 7, 36, 7, 986] -- Peso: 469
#
# Geração 9 -- Melhor Indivíduo: [19, 20, 7, 32, 7, 998] -- Peso: 493
#
# Geração 10 -- Melhor Indivíduo: [19, 20, 7, 32, 7, 998] -- Peso: 493
#
# Geração 11 -- Melhor Indivíduo: [5, 20, 26, 17, 12, 1001] -- Peso: 500
#
# Geração 12 -- Melhor Indivíduo: [5, 20, 26, 17, 12, 1001] -- Peso: 500
#
# Geração 13 -- Melhor Indivíduo: [19, 23, 6, 32, 7, 1006] -- Peso: 500
#
# Geração 14 -- Melhor Indivíduo: [19, 6, 7, 32, 12, 1039] -- Peso: 497
#
# Geração 15 -- Melhor Indivíduo: [19, 6, 7, 32, 12, 1039] -- Peso: 497
#
# Geração 16 -- Melhor Indivíduo: [19, 6, 7, 32, 12, 1039] -- Peso: 497
#
# Geração 17 -- Melhor Indivíduo: [19, 6, 7, 32, 12, 1039] -- Peso: 497
#
# Geração 18 -- Melhor Indivíduo: [5, 6, 7, 36, 12, 1045] -- Peso: 501
#
# Geração 19 -- Melhor Indivíduo: [5, 6, 7, 36, 12, 1045] -- Peso: 501
#
# Geração 20 -- Melhor Indivíduo: [5, 6, 7, 36, 12, 1045] -- Peso: 501
#
# Geração 21 -- Melhor Indivíduo: [5, 6, 7, 36, 12, 1045] -- Peso: 501
#
# Geração 22 -- Melhor Indivíduo: [5, 6, 7, 36, 12, 1045] -- Peso: 501
#
# Geração 23 -- Melhor Indivíduo: [5, 6, 7, 36, 12, 1045] -- Peso: 501
#
# Geração 24 -- Melhor Indivíduo: [5, 6, 7, 36, 12, 1045] -- Peso: 501
#
# Geração 25 -- Melhor Indivíduo: [5, 6, 7, 36, 12, 1045] -- Peso: 501
#
# Geração 26 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 27 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 28 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 29 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 30 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 31 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 32 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 33 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 34 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 35 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 36 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 37 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 38 -- Melhor Indivíduo: [5, 6, 6, 36, 12, 1059] -- Peso: 496
#
# Geração 39 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 40 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 41 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 42 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 43 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 44 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 45 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 46 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 47 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 48 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 49 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 50 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 51 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 52 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 53 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 54 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 55 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 56 -- Melhor Indivíduo: [6, 6, 6, 36, 12, 1062] -- Peso: 498
#
# Geração 57 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 58 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 59 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 60 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 61 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 62 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 63 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 64 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 65 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 66 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 67 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 68 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 69 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 70 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 71 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 72 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 73 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 74 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 75 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 76 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 77 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 78 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 79 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 80 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 81 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 82 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 83 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 84 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 85 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 86 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 87 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 88 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 89 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 90 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 91 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 92 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 93 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 94 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 95 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 96 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 97 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 98 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
#
# Geração 99 -- Melhor Indivíduo: [7, 6, 6, 36, 12, 1065] -- Peso: 500
