# %%
import numpy as np

# %%
# carregando os dados 
entradas = np.genfromtxt('iris.data', delimiter=',', usecols=(0,1,2,3))
saidas = np.genfromtxt('iris.data', delimiter=',', usecols=(4))

# %%
'''
Iris-setosa: 0
Iris-versicolor: 0
Iris-virginica: 0
'''

# utilizar 105 amostras para treino sendo 35 de cada 
entradas_treino = np.concatenate((entradas[:35], entradas[50:85], entradas[100:135]))
saidas_treino = np.concatenate((saidas[:35], saidas[50:85], saidas[100:135]))

# %%
entradas_teste = np.concatenate((entradas[35:50], entradas[85:100], entradas[135:]))
saidas_teste = np.concatenate((saidas[35:50], saidas[85:100], saidas[135:]))

# %%
from pybrain.datasets import SupervisedDataSet
from pybrain.tools.shortcuts import buildNetwork
from pybrain.supervised import BackpropTrainer

# %%
treinamento = SupervisedDataSet(4, 1)
for i in range(len(entradas_treino)):
    treinamento.addSample(entradas_treino[i], saidas_treino[i])

# %%
# construindo a rede 
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.3)

#treinando a rede
trainer.trainEpochs(1000)

# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.013 ]')
# ('correct:', '[0     ]')
# error:  0.00008237
# ('out:    ', '[0.006 ]')
# ('correct:', '[0     ]')
# error:  0.00001970
# ('out:    ', '[0.02  ]')
# ('correct:', '[0     ]')
# error:  0.00019296
# ('out:    ', '[0.027 ]')
# ('correct:', '[0     ]')
# error:  0.00035448
# ('out:    ', '[0.014 ]')
# ('correct:', '[0     ]')
# error:  0.00010410
# ('out:    ', '[0.012 ]')
# ('correct:', '[0     ]')
# error:  0.00007331
# ('out:    ', '[0.064 ]')
# ('correct:', '[0     ]')
# error:  0.00207075
# ('out:    ', '[0.021 ]')
# ('correct:', '[0     ]')
# error:  0.00021611
# ('out:    ', '[0.034 ]')
# ('correct:', '[0     ]')
# error:  0.00056985
# ('out:    ', '[0.023 ]')
# ('correct:', '[0     ]')
# error:  0.00025791
# ('out:    ', '[0.03  ]')
# ('correct:', '[0     ]')
# error:  0.00045192
# ('out:    ', '[0.009 ]')
# ('correct:', '[0     ]')
# error:  0.00004015
# ('out:    ', '[0.022 ]')
# ('correct:', '[0     ]')
# error:  0.00023126
# ('out:    ', '[0.008 ]')
# ('correct:', '[0     ]')
# error:  0.00002897
# ('out:    ', '[0.015 ]')
# ('correct:', '[0     ]')
# error:  0.00011487
# ('out:    ', '[1.103 ]')
# ('correct:', '[1     ]')
# error:  0.00528613
# ('out:    ', '[1.141 ]')
# ('correct:', '[1     ]')
# error:  0.00993286
# ('out:    ', '[1.308 ]')
# ('correct:', '[1     ]')
# error:  0.04747590
# ('out:    ', '[0.935 ]')
# ('correct:', '[1     ]')
# error:  0.00213618
# ('out:    ', '[1.155 ]')
# ('correct:', '[1     ]')
# error:  0.01198420
# ('out:    ', '[1.24  ]')
# ('correct:', '[1     ]')
# error:  0.02881382
# ('out:    ', '[1.181 ]')
# ('correct:', '[1     ]')
# error:  0.01639013
# ('out:    ', '[0.963 ]')
# ('correct:', '[1     ]')
# error:  0.00067396
# ('out:    ', '[0.755 ]')
# ('correct:', '[1     ]')
# error:  0.03012643
# ('out:    ', '[1.14  ]')
# ('correct:', '[1     ]')
# error:  0.00985663
# ('out:    ', '[0.89  ]')
# ('correct:', '[1     ]')
# error:  0.00605394
# ('out:    ', '[1.018 ]')
# ('correct:', '[1     ]')
# error:  0.00016073
# ('out:    ', '[0.97  ]')
# ('correct:', '[1     ]')
# error:  0.00044533
# ('out:    ', '[0.583 ]')
# ('correct:', '[1     ]')
# error:  0.08685759
# ('out:    ', '[1.015 ]')
# ('correct:', '[1     ]')
# error:  0.00011125
# ('out:    ', '[2.039 ]')
# ('correct:', '[2     ]')
# error:  0.00075677
# ('out:    ', '[1.998 ]')
# ('correct:', '[2     ]')
# error:  0.00000308
# ('out:    ', '[1.783 ]')
# ('correct:', '[2     ]')
# error:  0.02349275
# ('out:    ', '[1.599 ]')
# ('correct:', '[2     ]')
# error:  0.08026780
# ('out:    ', '[1.836 ]')
# ('correct:', '[2     ]')
# error:  0.01341036
# ('out:    ', '[2.025 ]')
# ('correct:', '[2     ]')
# error:  0.00032509
# ('out:    ', '[1.835 ]')
# ('correct:', '[2     ]')
# error:  0.01366935
# ('out:    ', '[1.898 ]')
# ('correct:', '[2     ]')
# error:  0.00520764
# ('out:    ', '[2.03  ]')
# ('correct:', '[2     ]')
# error:  0.00043630
# ('out:    ', '[2.037 ]')
# ('correct:', '[2     ]')
# error:  0.00068937
# ('out:    ', '[1.917 ]')
# ('correct:', '[2     ]')
# error:  0.00344413
# ('out:    ', '[1.868 ]')
# ('correct:', '[2     ]')
# error:  0.00874867
# ('out:    ', '[1.802 ]')
# ('correct:', '[2     ]')
# error:  0.01967539
# ('out:    ', '[1.92  ]')
# ('correct:', '[2     ]')
# error:  0.00317790
# ('out:    ', '[1.74  ]')
# ('correct:', '[2     ]')
# error:  0.03380901
# ('All errors:', [8.2365443751240616e-05, 1.9701675547105465e-05, 0.00019296268698766256, 0.00035447572864766758, 0.00010409839630217301, 7.3308293493331916e-05, 0.0020707499546454514, 0.00021611262578551647, 0.00056985083732077912, 0.00025791159285841247, 0.00045191979568431792, 4.0150724817045305e-05, 0.00023125510808205622, 2.8966990932932285e-05, 0.0001148708729242821, 0.0052861332664439009, 0.0099328588942467922, 0.047475900182386836, 0.0021361766395304915, 0.011984204677493827, 0.02881381790102374, 0.016390131561812168, 0.00067395708021917699, 0.030126427819056799, 0.0098566256618724778, 0.0060539373002151198, 0.00016073051805365237, 0.00044533316598197335, 0.086857594303941202, 0.00011125149404929554, 0.00075676782260467946, 3.077082729732986e-06, 0.023492749776684849, 0.080267804341896121, 0.013410360954135583, 0.00032508949993675554, 0.013669346024552203, 0.00520763662499965, 0.00043629870375144758, 0.00068937049977734084, 0.0034441347816570088, 0.0087486744863345314, 0.019675386257141384, 0.0031779038257169112, 0.033809009988541389])
# ('Average error:', 0.010405053152545933)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-0fddf0604220> in <module>()
#      10 for i in range(len(entradas_teste)):
#      11     teste.addSample(entradas_teste[i], saidas_teste[i])
# ---> 12 trainer.testOnData(teste, verbose=True)
#
# ~\Anaconda3\lib\site-packages\pybrain\supervised\trainers\backprop.py in testOnData(self, dataset, verbose)
#     159             print(('Average error:', avgErr))
#     160             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 161                    sorted(ponderatedErrors)[len(errors) / 2]))
#     162         return avgErr
#     163
#
# TypeError: list indices must be integers or slices, not float

# %%
# construindo a rede 
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.9)

#treinando a rede
trainer.trainEpochs(1000)

# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.017 ]')
# ('correct:', '[0     ]')
# error:  0.00015134
# ('out:    ', '[0.013 ]')
# ('correct:', '[0     ]')
# error:  0.00008433
# ('out:    ', '[0.014 ]')
# ('correct:', '[0     ]')
# error:  0.00009982
# ('out:    ', '[-0.001]')
# ('correct:', '[0     ]')
# error:  0.00000035
# ('out:    ', '[-0.003]')
# ('correct:', '[0     ]')
# error:  0.00000439
# ('out:    ', '[-0.011]')
# ('correct:', '[0     ]')
# error:  0.00005845
# ('out:    ', '[0.357 ]')
# ('correct:', '[0     ]')
# error:  0.06354835
# ('out:    ', '[-0.016]')
# ('correct:', '[0     ]')
# error:  0.00012656
# ('out:    ', '[0.003 ]')
# ('correct:', '[0     ]')
# error:  0.00000318
# ('out:    ', '[-0.021]')
# ('correct:', '[0     ]')
# error:  0.00022751
# ('out:    ', '[0.046 ]')
# ('correct:', '[0     ]')
# error:  0.00104351
# ('out:    ', '[-0.024]')
# ('correct:', '[0     ]')
# error:  0.00028474
# ('out:    ', '[-0.009]')
# ('correct:', '[0     ]')
# error:  0.00004240
# ('out:    ', '[-0.016]')
# ('correct:', '[0     ]')
# error:  0.00013507
# ('out:    ', '[0.002 ]')
# ('correct:', '[0     ]')
# error:  0.00000248
# ('out:    ', '[0.725 ]')
# ('correct:', '[1     ]')
# error:  0.03781453
# ('out:    ', '[1.043 ]')
# ('correct:', '[1     ]')
# error:  0.00093416
# ('out:    ', '[1.134 ]')
# ('correct:', '[1     ]')
# error:  0.00895101
# ('out:    ', '[0.707 ]')
# ('correct:', '[1     ]')
# error:  0.04306829
# ('out:    ', '[1.051 ]')
# ('correct:', '[1     ]')
# error:  0.00129678
# ('out:    ', '[1.146 ]')
# ('correct:', '[1     ]')
# error:  0.01059699
# ('out:    ', '[1.012 ]')
# ('correct:', '[1     ]')
# error:  0.00006867
# ('out:    ', '[0.992 ]')
# ('correct:', '[1     ]')
# error:  0.00002915
# ('out:    ', '[0.877 ]')
# ('correct:', '[1     ]')
# error:  0.00760547
# ('out:    ', '[0.998 ]')
# ('correct:', '[1     ]')
# error:  0.00000241
# ('out:    ', '[0.698 ]')
# ('correct:', '[1     ]')
# error:  0.04561465
# ('out:    ', '[0.851 ]')
# ('correct:', '[1     ]')
# error:  0.01102729
# ('out:    ', '[0.977 ]')
# ('correct:', '[1     ]')
# error:  0.00026881
# ('out:    ', '[0.817 ]')
# ('correct:', '[1     ]')
# error:  0.01672378
# ('out:    ', '[0.913 ]')
# ('correct:', '[1     ]')
# error:  0.00379632
# ('out:    ', '[2.083 ]')
# ('correct:', '[2     ]')
# error:  0.00346264
# ('out:    ', '[2.008 ]')
# ('correct:', '[2     ]')
# error:  0.00002919
# ('out:    ', '[1.975 ]')
# ('correct:', '[2     ]')
# error:  0.00032141
# ('out:    ', '[1.721 ]')
# ('correct:', '[2     ]')
# error:  0.03890711
# ('out:    ', '[1.975 ]')
# ('correct:', '[2     ]')
# error:  0.00030531
# ('out:    ', '[2.082 ]')
# ('correct:', '[2     ]')
# error:  0.00332607
# ('out:    ', '[1.901 ]')
# ('correct:', '[2     ]')
# error:  0.00489203
# ('out:    ', '[2.041 ]')
# ('correct:', '[2     ]')
# error:  0.00082447
# ('out:    ', '[2.077 ]')
# ('correct:', '[2     ]')
# error:  0.00294822
# ('out:    ', '[2.073 ]')
# ('correct:', '[2     ]')
# error:  0.00268442
# ('out:    ', '[2.038 ]')
# ('correct:', '[2     ]')
# error:  0.00072692
# ('out:    ', '[2.025 ]')
# ('correct:', '[2     ]')
# error:  0.00031495
# ('out:    ', '[1.974 ]')
# ('correct:', '[2     ]')
# error:  0.00033018
# ('out:    ', '[1.966 ]')
# ('correct:', '[2     ]')
# error:  0.00058542
# ('out:    ', '[1.914 ]')
# ('correct:', '[2     ]')
# error:  0.00366473
# ('All errors:', [0.00015133765107834681, 8.4325912746915772e-05, 9.9824356538976157e-05, 3.4977317316302638e-07, 4.3916562497611004e-06, 5.8454573501303799e-05, 0.063548345388035485, 0.00012655925998254647, 3.1760480710102251e-06, 0.0002275125044448672, 0.0010435075372164492, 0.0002847420355302866, 4.2397409876480264e-05, 0.00013507292466383343, 2.4820392720626701e-06, 0.037814529425701529, 0.00093415986833745484, 0.0089510069331861404, 0.043068290603831154, 0.0012967760188256911, 0.010596985102918632, 6.8671199876454533e-05, 2.9147449927570424e-05, 0.0076054665570264544, 2.4095595012797218e-06, 0.045614646574174189, 0.011027294811628331, 0.00026881134989731851, 0.01672377520347099, 0.0037963163009465126, 0.0034626402357274318, 2.9189179207602477e-05, 0.00032141357606915288, 0.038907105350161474, 0.00030530732696425487, 0.0033260682277178799, 0.0048920343800157211, 0.00082446954969466575, 0.0029482233304216642, 0.0026844225244215957, 0.00072691922490232346, 0.00031495150213754839, 0.00033018479332142566, 0.00058542498818302789, 0.0036647318077476856])
# ('Average error:', 0.0070429744894738803)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-1019ae8f5d2d> in <module>()
#      10 for i in range(len(entradas_teste)):
#      11     teste.addSample(entradas_teste[i], saidas_teste[i])
# ---> 12 trainer.testOnData(teste, verbose=True)
#
# ~\Anaconda3\lib\site-packages\pybrain\supervised\trainers\backprop.py in testOnData(self, dataset, verbose)
#     159             print(('Average error:', avgErr))
#     160             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 161                    sorted(ponderatedErrors)[len(errors) / 2]))
#     162         return avgErr
#     163
#
# TypeError: list indices must be integers or slices, not float

# %%
# construindo a rede 
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.005, momentum=0.9)

#treinando a rede
trainer.trainEpochs(2000)

# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.039 ]')
# ('correct:', '[0     ]')
# error:  0.00075798
# ('out:    ', '[0.036 ]')
# ('correct:', '[0     ]')
# error:  0.00063900
# ('out:    ', '[0.052 ]')
# ('correct:', '[0     ]')
# error:  0.00137200
# ('out:    ', '[0.051 ]')
# ('correct:', '[0     ]')
# error:  0.00128212
# ('out:    ', '[0.046 ]')
# ('correct:', '[0     ]')
# error:  0.00104356
# ('out:    ', '[0.039 ]')
# ('correct:', '[0     ]')
# error:  0.00075195
# ('out:    ', '[0.102 ]')
# ('correct:', '[0     ]')
# error:  0.00523388
# ('out:    ', '[0.045 ]')
# ('correct:', '[0     ]')
# error:  0.00099155
# ('out:    ', '[0.07  ]')
# ('correct:', '[0     ]')
# error:  0.00246515
# ('out:    ', '[0.067 ]')
# ('correct:', '[0     ]')
# error:  0.00226350
# ('out:    ', '[0.06  ]')
# ('correct:', '[0     ]')
# error:  0.00182688
# ('out:    ', '[0.04  ]')
# ('correct:', '[0     ]')
# error:  0.00080716
# ('out:    ', '[0.049 ]')
# ('correct:', '[0     ]')
# error:  0.00118507
# ('out:    ', '[0.038 ]')
# ('correct:', '[0     ]')
# error:  0.00073529
# ('out:    ', '[0.044 ]')
# ('correct:', '[0     ]')
# error:  0.00097601
# ('out:    ', '[1.035 ]')
# ('correct:', '[1     ]')
# error:  0.00060471
# ('out:    ', '[1.023 ]')
# ('correct:', '[1     ]')
# error:  0.00025417
# ('out:    ', '[1.064 ]')
# ('correct:', '[1     ]')
# error:  0.00206869
# ('out:    ', '[1.007 ]')
# ('correct:', '[1     ]')
# error:  0.00002743
# ('out:    ', '[1.041 ]')
# ('correct:', '[1     ]')
# error:  0.00083473
# ('out:    ', '[1.121 ]')
# ('correct:', '[1     ]')
# error:  0.00727601
# ('out:    ', '[1.054 ]')
# ('correct:', '[1     ]')
# error:  0.00146746
# ('out:    ', '[1.005 ]')
# ('correct:', '[1     ]')
# error:  0.00001443
# ('out:    ', '[0.981 ]')
# ('correct:', '[1     ]')
# error:  0.00017496
# ('out:    ', '[1.045 ]')
# ('correct:', '[1     ]')
# error:  0.00099215
# ('out:    ', '[1.005 ]')
# ('correct:', '[1     ]')
# error:  0.00001173
# ('out:    ', '[1.017 ]')
# ('correct:', '[1     ]')
# error:  0.00014269
# ('out:    ', '[1.007 ]')
# ('correct:', '[1     ]')
# error:  0.00002292
# ('out:    ', '[0.948 ]')
# ('correct:', '[1     ]')
# error:  0.00135195
# ('out:    ', '[1.014 ]')
# ('correct:', '[1     ]')
# error:  0.00009180
# ('out:    ', '[2.026 ]')
# ('correct:', '[2     ]')
# error:  0.00034455
# ('out:    ', '[2.03  ]')
# ('correct:', '[2     ]')
# error:  0.00043783
# ('out:    ', '[1.959 ]')
# ('correct:', '[2     ]')
# error:  0.00085271
# ('out:    ', '[1.642 ]')
# ('correct:', '[2     ]')
# error:  0.06420286
# ('out:    ', '[1.937 ]')
# ('correct:', '[2     ]')
# error:  0.00198252
# ('out:    ', '[2.029 ]')
# ('correct:', '[2     ]')
# error:  0.00042129
# ('out:    ', '[1.893 ]')
# ('correct:', '[2     ]')
# error:  0.00576192
# ('out:    ', '[2.016 ]')
# ('correct:', '[2     ]')
# error:  0.00012167
# ('out:    ', '[2.03  ]')
# ('correct:', '[2     ]')
# error:  0.00046256
# ('out:    ', '[2.03  ]')
# ('correct:', '[2     ]')
# error:  0.00046469
# ('out:    ', '[1.994 ]')
# ('correct:', '[2     ]')
# error:  0.00001952
# ('out:    ', '[1.975 ]')
# ('correct:', '[2     ]')
# error:  0.00032189
# ('out:    ', '[1.928 ]')
# ('correct:', '[2     ]')
# error:  0.00261772
# ('out:    ', '[2.02  ]')
# ('correct:', '[2     ]')
# error:  0.00019461
# ('out:    ', '[1.936 ]')
# ('correct:', '[2     ]')
# error:  0.00205355
# ('All errors:', [0.00075798082608259383, 0.00063900313938857975, 0.0013719979987328269, 0.0012821220870784761, 0.0010435617404709354, 0.00075195421050964454, 0.0052338812678129794, 0.00099154592414859351, 0.0024651512378548544, 0.0022634991728711098, 0.0018268763999522231, 0.00080715862766588009, 0.0011850702329990633, 0.00073528889810287469, 0.00097600856089318801, 0.00060471370691160943, 0.00025416902170331232, 0.0020686942182665232, 2.7431415266962295e-05, 0.00083473314065780403, 0.0072760114822815304, 0.0014674641309405678, 1.4428139833129992e-05, 0.00017495582579118646, 0.00099215141708844596, 1.1732087980301598e-05, 0.00014269347077558716, 2.2924692433747001e-05, 0.0013519500051793623, 9.1799148415491343e-05, 0.00034454859174792081, 0.00043782727756581458, 0.00085270951304635507, 0.064202864693604658, 0.0019825176252806134, 0.00042129474543191613, 0.0057619199257445885, 0.0001216687815350698, 0.00046256274329973754, 0.00046469306469311839, 1.9519530966139065e-05, 0.00032188544859304243, 0.0026177208229836799, 0.00019461079611159341, 0.0020535498815996782])
# ('Average error:', 0.0026205965704509623)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-d84e73e2281a> in <module>()
#      10 for i in range(len(entradas_teste)):
#      11     teste.addSample(entradas_teste[i], saidas_teste[i])
# ---> 12 trainer.testOnData(teste, verbose=True)
#
# ~\Anaconda3\lib\site-packages\pybrain\supervised\trainers\backprop.py in testOnData(self, dataset, verbose)
#     159             print(('Average error:', avgErr))
#     160             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 161                    sorted(ponderatedErrors)[len(errors) / 2]))
#     162         return avgErr
#     163
#
# TypeError: list indices must be integers or slices, not float

# %%
# Esse diabo nunca compila
# E quando compila ainda sai um resultado horrível :/

# construindo a rede 
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.1, momentum=0.9)

#treinando a rede
trainer.trainEpochs(10000)

# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505037
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505041
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505040
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505035
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505041
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505039
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505031
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505035
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505041
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505042
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505039
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505041
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505039
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505041
# ('out:    ', '[0.3   ]')
# ('correct:', '[0     ]')
# error:  0.04505040
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[1     ]')
# error:  0.24488241
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('out:    ', '[0.3   ]')
# ('correct:', '[2     ]')
# error:  1.44471439
# ('All errors:', [0.045050374920424123, 0.045050407076483522, 0.045050404963428249, 0.045050346079176545, 0.045050409784258769, 0.045050394161234741, 0.045050305475759868, 0.045050345932851725, 0.045050411120111468, 0.045050416536317917, 0.045050392721407803, 0.045050413383220883, 0.045050387463830929, 0.04505041249611879, 0.045050402329047466, 0.24488240541655606, 0.24488240541292072, 0.24488240543105455, 0.24488240544551659, 0.24488240552113338, 0.24488240543842302, 0.24488240541642936, 0.24488240547058049, 0.24488240666802152, 0.24488240545251508, 0.24488240543159565, 0.24488240543824075, 0.24488240542269529, 0.24488240755885982, 0.24488240545299936, 1.4447143929776511, 1.4447143929788209, 1.4447143929786792, 1.444714392991951, 1.4447143929787853, 1.4447143929788377, 1.4447143929811972, 1.4447143929916284, 1.4447143929779243, 1.4447143929783599, 1.4447143929815824, 1.4447143929919812, 1.4447143929810276, 1.4447143929797401, 1.4447143929845636])
# ('Average error:', 0.57821572898119866)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-27e0c075e770> in <module>()
#      10 for i in range(len(entradas_teste)):
#      11     teste.addSample(entradas_teste[i], saidas_teste[i])
# ---> 12 trainer.testOnData(teste, verbose=True)
#
# ~\Anaconda3\lib\site-packages\pybrain\supervised\trainers\backprop.py in testOnData(self, dataset, verbose)
#     159             print(('Average error:', avgErr))
#     160             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 161                    sorted(ponderatedErrors)[len(errors) / 2]))
#     162         return avgErr
#     163
#
# TypeError: list indices must be integers or slices, not float
